# %%
# !pip install Sastrawi
# Out:
# Requirement already satisfied: Sastrawi in /usr/local/lib/python3.12/dist-packages (1.0.1)

# %%
dokumen = {
    "d1": "Dosen-dosen Unitama sedang melaksanakan rapat koordinasi dosen di aula kampus Unitama.",
    "d2": "Pasnur merupakan salah seorang dosen di kampus Unitama Makassar.",
    "d3": "Bagaimana keakraban dosen-dosen dan mahasiswa-mahasiswa di kampus Unitama?",
    "d4": "Kota Makassar merupakan kota terbesar di Sulawesi Selatan dan dicanangkan sebagai kota dunia.",
    "d5": "Perkenalkan nama saya Muhammad Bintang Ramli, saya berasal dari Kota Makassar Kelurahan Sudiang, Saya Suka Membaca Buku, Dan Belajar Koding 😁👍.",
    "d6": "Saya merasa mata kuliah sistem temu kembali informasi cukup menarik untuk dipelajari, dan saya berharap disini saya mendapatkan ilmu yang banyak karena saya suka sekali dengan STKI (sistem temu kembali).",
    "q": "Dosen Unitama Makassar"
}

# %%
import pandas as pd

df = pd.DataFrame(list(dokumen.items()), columns=["id_dokumen", "isi_dokumen"])
df
# Out:
#   id_dokumen                                        isi_dokumen
# 0         d1  Dosen-dosen Unitama sedang melaksanakan rapat ...
# 1         d2  Pasnur merupakan salah seorang dosen di kampus...
# 2         d3  Bagaimana keakraban dosen-dosen dan mahasiswa-...
# 3         d4  Kota Makassar merupakan kota terbesar di Sulaw...
# 4         d5  Perkenalkan nama saya Muhammad Bintang Ramli, ...
# 5         d6  Saya merasa mata kuliah sistem temu kembali in...
# 6          q                             Dosen Unitama Makassar

# %%
def case_folding(text):
    return text.lower()

# %%
df["isi_casefold"] = df["isi_dokumen"].apply(case_folding)
df
# Out:
#   id_dokumen                                        isi_dokumen  \
# 0         d1  Dosen-dosen Unitama sedang melaksanakan rapat ...
# 1         d2  Pasnur merupakan salah seorang dosen di kampus...
# 2         d3  Bagaimana keakraban dosen-dosen dan mahasiswa-...
# 3         d4  Kota Makassar merupakan kota terbesar di Sulaw...
# 4         d5  Perkenalkan nama saya Muhammad Bintang Ramli, ...
# 5         d6  Saya merasa mata kuliah sistem temu kembali in...
# 6          q                             Dosen Unitama Makassar
#
#                                         isi_casefold
# 0  dosen-dosen unitama sedang melaksanakan rapat ...
# 1  pasnur merupakan salah seorang dosen di kampus...
# 2  bagaimana keakraban dosen-dosen dan mahasiswa-...
# 3  kota makassar merupakan kota terbesar di sulaw...
# 4  perkenalkan nama saya muhammad bintang ramli, ...
# 5  saya merasa mata kuliah sistem temu kembali in...
# 6                             dosen unitama makassar

# %%
import re

def filtering(text):
    text = re.sub(r'[^a-zA-Z\s]', ' ', text)
    text = re.sub(r'\s+', ' ', text)
    return text.strip()

# %%
df["isi_filtered"] = df["isi_casefold"].apply(filtering)
df
# Out:
#   id_dokumen                                        isi_dokumen  \
# 0         d1  Dosen-dosen Unitama sedang melaksanakan rapat ...
# 1         d2  Pasnur merupakan salah seorang dosen di kampus...
# 2         d3  Bagaimana keakraban dosen-dosen dan mahasiswa-...
# 3         d4  Kota Makassar merupakan kota terbesar di Sulaw...
# 4         d5  Perkenalkan nama saya Muhammad Bintang Ramli, ...
# 5         d6  Saya merasa mata kuliah sistem temu kembali in...
# 6          q                             Dosen Unitama Makassar
#
#                                         isi_casefold  \
# 0  dosen-dosen unitama sedang melaksanakan rapat ...
# 1  pasnur merupakan salah seorang dosen di kampus...
# 2  bagaimana keakraban dosen-dosen dan mahasiswa-...
# 3  kota makassar merupakan kota terbesar di sulaw...
# 4  perkenalkan nama saya muhammad bintang ramli, ...
# 5  saya merasa mata kuliah sistem temu kembali in...
# 6                             dosen unitama makassar
#
#                                         isi_filtered
# 0  dosen dosen unitama sedang melaksanakan rapat ...
# 1  pasnur merupakan salah seorang dosen di kampus...
# 2  bagaimana keakraban dosen dosen dan mahasiswa ...
# 3  kota makassar merupakan kota terbesar di sulaw...
# 4  perkenalkan nama saya muhammad bintang ramli s...
# 5  saya merasa mata kuliah sistem temu kembali in...
# 6                             dosen unitama makassar

# %%
from Sastrawi.StopWordRemover.StopWordRemoverFactory import StopWordRemoverFactory

factory = StopWordRemoverFactory()
stopword = factory.create_stop_word_remover()

def remove_stopword(text):
    return stopword.remove(text)

# %%
df["isi_stopword"] = df["isi_filtered"].apply(remove_stopword)
df
# Out:
#   id_dokumen                                        isi_dokumen  \
# 0         d1  Dosen-dosen Unitama sedang melaksanakan rapat ...
# 1         d2  Pasnur merupakan salah seorang dosen di kampus...
# 2         d3  Bagaimana keakraban dosen-dosen dan mahasiswa-...
# 3         d4  Kota Makassar merupakan kota terbesar di Sulaw...
# 4         d5  Perkenalkan nama saya Muhammad Bintang Ramli, ...
# 5         d6  Saya merasa mata kuliah sistem temu kembali in...
# 6          q                             Dosen Unitama Makassar
#
#                                         isi_casefold  \
# 0  dosen-dosen unitama sedang melaksanakan rapat ...
# 1  pasnur merupakan salah seorang dosen di kampus...
# 2  bagaimana keakraban dosen-dosen dan mahasiswa-...
# 3  kota makassar merupakan kota terbesar di sulaw...
# 4  perkenalkan nama saya muhammad bintang ramli, ...
# 5  saya merasa mata kuliah sistem temu kembali in...
# 6                             dosen unitama makassar
#
#                                         isi_filtered  \
# 0  dosen dosen unitama sedang melaksanakan rapat ...
# 1  pasnur merupakan salah seorang dosen di kampus...
# 2  bagaimana keakraban dosen dosen dan mahasiswa ...
# 3  kota makassar merupakan kota terbesar di sulaw...
# 4  perkenalkan nama saya muhammad bintang ramli s...
# 5  saya merasa mata kuliah sistem temu kembali in...
# 6                             dosen unitama makassar
#
#                                         isi_stopword
# 0  dosen dosen unitama sedang melaksanakan rapat ...
# 1  pasnur merupakan salah seorang dosen kampus un...
# 2  bagaimana keakraban dosen dosen mahasiswa maha...
# 3  kota makassar merupakan kota terbesar sulawesi...
# 4  perkenalkan nama muhammad bintang ramli berasa...
# 5  merasa mata kuliah sistem temu informasi cukup...
# 6                             dosen unitama makassar

# %%
from Sastrawi.Stemmer.StemmerFactory import StemmerFactory

factory = StemmerFactory()
stemmer = factory.create_stemmer()

def stemming(text):
    return stemmer.stem(text)

# %%
df["isi_stem"] = df["isi_stopword"].apply(stemming)
df
# Out:
#   id_dokumen                                        isi_dokumen  \
# 0         d1  Dosen-dosen Unitama sedang melaksanakan rapat ...
# 1         d2  Pasnur merupakan salah seorang dosen di kampus...
# 2         d3  Bagaimana keakraban dosen-dosen dan mahasiswa-...
# 3         d4  Kota Makassar merupakan kota terbesar di Sulaw...
# 4         d5  Perkenalkan nama saya Muhammad Bintang Ramli, ...
# 5         d6  Saya merasa mata kuliah sistem temu kembali in...
# 6          q                             Dosen Unitama Makassar
#
#                                         isi_casefold  \
# 0  dosen-dosen unitama sedang melaksanakan rapat ...
# 1  pasnur merupakan salah seorang dosen di kampus...
# 2  bagaimana keakraban dosen-dosen dan mahasiswa-...
# 3  kota makassar merupakan kota terbesar di sulaw...
# 4  perkenalkan nama saya muhammad bintang ramli, ...
# 5  saya merasa mata kuliah sistem temu kembali in...
# 6                             dosen unitama makassar
#
#                                         isi_filtered  \
# 0  dosen dosen unitama sedang melaksanakan rapat ...
# 1  pasnur merupakan salah seorang dosen di kampus...
# 2  bagaimana keakraban dosen dosen dan mahasiswa ...
# 3  kota makassar merupakan kota terbesar di sulaw...
# 4  perkenalkan nama saya muhammad bintang ramli s...
# 5  saya merasa mata kuliah sistem temu kembali in...
# 6                             dosen unitama makassar
#
#                                         isi_stopword  \
# 0  dosen dosen unitama sedang melaksanakan rapat ...
# 1  pasnur merupakan salah seorang dosen kampus un...
# 2  bagaimana keakraban dosen dosen mahasiswa maha...
# 3  kota makassar merupakan kota terbesar sulawesi...
# 4  perkenalkan nama muhammad bintang ramli berasa...
# 5  merasa mata kuliah sistem temu informasi cukup...
# 6                             dosen unitama makassar
#
#                                             isi_stem
# 0  dosen dosen unitama sedang laksana rapat koord...
# 1  pasnur rupa salah orang dosen kampus unitama m...
# 2  bagaimana akrab dosen dosen mahasiswa mahasisw...
# 3  kota makassar rupa kota besar sulawesi selatan...
# 4  kenal nama muhammad bintang ramli asal kota ma...
# 5  rasa mata kuliah sistem temu informasi cukup t...
# 6                             dosen unitama makassar

# %%
df_clean = df[["id_dokumen", "isi_stem"]].copy()
df_clean.columns = ["id_dokumen", "isi_dokumen"]
df_clean
# Out:
#   id_dokumen                                        isi_dokumen
# 0         d1  dosen dosen unitama sedang laksana rapat koord...
# 1         d2  pasnur rupa salah orang dosen kampus unitama m...
# 2         d3  bagaimana akrab dosen dosen mahasiswa mahasisw...
# 3         d4  kota makassar rupa kota besar sulawesi selatan...
# 4         d5  kenal nama muhammad bintang ramli asal kota ma...
# 5         d6  rasa mata kuliah sistem temu informasi cukup t...
# 6          q                             dosen unitama makassar

# %%
from sklearn.feature_extraction.text import CountVectorizer
import pandas as pd

vectorizer = CountVectorizer()
X = vectorizer.fit_transform(df_clean["isi_dokumen"])

tf_df = pd.DataFrame(
    X.toarray(),
    columns=vectorizer.get_feature_names_out(),
    index=df_clean["id_dokumen"]
)

tf_transpose = tf_df.T

tf_transpose.reset_index(inplace=True)
tf_transpose.rename(columns={"index": "Term/Kata"}, inplace=True)

tf_transpose
# Out:
# id_dokumen   Term/Kata  d1  d2  d3  d4  d5  d6  q
# 0                 ajar   0   0   0   0   1   1  0
# 1                akrab   0   0   1   0   0   0  0
# 2                 asal   0   0   0   0   1   0  0
# 3                 aula   1   0   0   0   0   0  0
# 4                 baca   0   0   0   0   1   0  0
# 5            bagaimana   0   0   1   0   0   0  0
# 6               banyak   0   0   0   0   0   1  0
# 7                besar   0   0   0   1   0   0  0
# 8              bintang   0   0   0   0   1   0  0
# 9                 buku   0   0   0   0   1   0  0
# 10              canang   0   0   0   1   0   0  0
# 11               cukup   0   0   0   0   0   1  0
# 12               dapat   0   0   0   0   0   1  0
# 13               dosen   3   1   2   0   0   0  1
# 14               dunia   0   0   0   1   0   0  0
# 15               harap   0   0   0   0   0   1  0
# 16                ilmu   0   0   0   0   0   1  0
# 17           informasi   0   0   0   0   0   1  0
# 18              kampus   1   1   1   0   0   0  0
# 19               kenal   0   0   0   0   1   0  0
# 20              koding   0   0   0   0   1   0  0
# 21          koordinasi   1   0   0   0   0   0  0
# 22                kota   0   0   0   3   1   0  0
# 23              kuliah   0   0   0   0   0   1  0
# 24             laksana   1   0   0   0   0   0  0
# 25               lurah   0   0   0   0   1   0  0
# 26           mahasiswa   0   0   2   0   0   0  0
# 27            makassar   0   1   0   1   1   0  1
# 28                mata   0   0   0   0   0   1  0
# 29            muhammad   0   0   0   0   1   0  0
# 30                nama   0   0   0   0   1   0  0
# 31               orang   0   1   0   0   0   0  0
# 32              pasnur   0   1   0   0   0   0  0
# 33               ramli   0   0   0   0   1   0  0
# 34               rapat   1   0   0   0   0   0  0
# 35                rasa   0   0   0   0   0   1  0
# 36                rupa   0   1   0   1   0   0  0
# 37               salah   0   1   0   0   0   0  0
# 38                saya   0   0   0   0   0   2  0
# 39              sedang   1   0   0   0   0   0  0
# 40              sekali   0   0   0   0   0   1  0
# 41             selatan   0   0   0   1   0   0  0
# 42                sini   0   0   0   0   0   1  0
# 43              sistem   0   0   0   0   0   2  0
# 44                stki   0   0   0   0   0   1  0
# 45             sudiang   0   0   0   0   1   0  0
# 46                suka   0   0   0   0   1   1  0
# 47            sulawesi   0   0   0   1   0   0  0
# 48               tarik   0   0   0   0   0   1  0
# 49                temu   0   0   0   0   0   2  0
# 50             unitama   2   1   1   0   0   0  1

# %%
from sklearn.feature_extraction.text import TfidfVectorizer
import pandas as pd

tfidf_vectorizer = TfidfVectorizer(
    use_idf=True,
    smooth_idf=True,
    sublinear_tf=False,
    norm=None
)

tfidf_matrix = tfidf_vectorizer.fit_transform(df_clean["isi_dokumen"])

tfidf_df = pd.DataFrame(
    tfidf_matrix.toarray(),
    columns=tfidf_vectorizer.get_feature_names_out()
)

tfidf_df.insert(0, "id_dokumen", df_clean["id_dokumen"])

tfidf_df
# Out:
#   id_dokumen      ajar     akrab      asal      aula      baca  bagaimana  \
# 0         d1  0.000000  0.000000  0.000000  2.386294  0.000000   0.000000
# 1         d2  0.000000  0.000000  0.000000  0.000000  0.000000   0.000000
# 2         d3  0.000000  2.386294  0.000000  0.000000  0.000000   2.386294
# 3         d4  0.000000  0.000000  0.000000  0.000000  0.000000   0.000000
# 4         d5  1.980829  0.000000  2.386294  0.000000  2.386294   0.000000
# 5         d6  1.980829  0.000000  0.000000  0.000000  0.000000   0.000000
# 6          q  0.000000  0.000000  0.000000  0.000000  0.000000   0.000000
#
#      banyak     besar   bintang  ...   selatan      sini    sistem      stki  \
# 0  0.000000  0.000000  0.000000  ...  0.000000  0.000000  0.000000  0.000000
# 1  0.000000  0.000000  0.000000  ...  0.000000  0.000000  0.000000  0.000000
# 2  0.000000  0.000000  0.000000  ...  0.000000  0.000000  0.000000  0.000000
# 3  0.000000  2.386294  0.000000  ...  2.386294  0.000000  0.000000  0.000000
# 4  0.000000  0.000000  2.386294  ...  0.000000  0.000000  0.000000  0.000000
# 5  2.386294  0.000000  0.000000  ...  0.000000  2.386294  4.772589  2.386294
# 6  0.000000  0.000000  0.000000  ...  0.000000  0.000000  0.000000  0.000000
#
#     sudiang      suka  sulawesi     tarik      temu   unitama
# 0  0.000000  0.000000  0.000000  0.000000  0.000000  2.940007
# 1  0.000000  0.000000  0.000000  0.000000  0.000000  1.470004
# 2  0.000000  0.000000  0.000000  0.000000  0.000000  1.470004
# 3  0.000000  0.000000  2.386294  0.000000  0.000000  0.000000
# 4  2.386294  1.980829  0.000000  0.000000  0.000000  0.000000
# 5  0.000000  1.980829  0.000000  2.386294  4.772589  0.000000
# 6  0.000000  0.000000  0.000000  0.000000  0.000000  1.470004
#
# [7 rows x 52 columns]

# %%
import numpy as np

query_vec = tfidf_df[tfidf_df["id_dokumen"] == "q"].drop(columns=["id_dokumen"]).values[0]

hasil = []

for i, row in tfidf_df.iterrows():
    if row["id_dokumen"] == "q":
        continue

    doc_vec = row.drop("id_dokumen").values

    dot = np.dot(query_vec, doc_vec)
    norm_q = np.linalg.norm(query_vec)
    norm_d = np.linalg.norm(doc_vec)

    sim = dot / (norm_q * norm_d)

    hasil.append((row["id_dokumen"], sim))

sim_df = pd.DataFrame(hasil, columns=["id_dokumen", "cosine_similarity"])
sim_df = sim_df.sort_values(by="cosine_similarity", ascending=False)

sim_df
# Out:
#   id_dokumen  cosine_similarity
# 0         d1           0.550456
# 1         d2           0.462119
# 2         d3           0.368124
# 3         d4           0.101534
# 4         d5           0.096990
# 5         d6           0.000000

# %%
threshold = 0.2

# %%
import seaborn as sns
import matplotlib.pyplot as plt

relevansi = {
    "d1":1, "d2":1, "d3":1,
    "d4":0, "d5":0, "d6":0
}

sim_df["prediksi"] = sim_df["cosine_similarity"].apply(lambda x: 1 if x >= threshold else 0)
sim_df["aktual"] = sim_df["id_dokumen"].map(relevansi)

TP = len(sim_df[(sim_df.prediksi==1)&(sim_df.aktual==1)])
FP = len(sim_df[(sim_df.prediksi==1)&(sim_df.aktual==0)])
FN = len(sim_df[(sim_df.prediksi==0)&(sim_df.aktual==1)])
TN = len(sim_df[(sim_df.prediksi==0)&(sim_df.aktual==0)])

cm = [[TP, FP],[FN, TN]]

sns.heatmap(cm, annot=True, fmt="d",
            xticklabels=["Relevan","Tidak Relevan"],
            yticklabels=["Retrieve","Tidak Retrieve"])
plt.show()

# %%
precision = TP/(TP+FP)
recall = TP/(TP+FN)
f1 = 2*(precision*recall)/(precision+recall)
accuracy = (TP+TN)/(TP+TN+FP+FN)

print("TP:", TP)
print("FP:", FP)
print("FN:", FN)
print("TN:", TN)
print("Precision:", precision)
print("Recall:", recall)
print("F1 Score:", f1)
print("Accuracy:", accuracy)
# Out:
# TP: 3
# FP: 0
# FN: 0
# TN: 3
# Precision: 1.0
# Recall: 1.0
# F1 Score: 1.0
# Accuracy: 1.0
